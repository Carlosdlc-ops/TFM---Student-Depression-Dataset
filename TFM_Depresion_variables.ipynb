# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"D:\Descargas\student_depression_dataset.csv")

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
print(df["Work Pressure"].unique())
# Out:
# [0. 5. 2.]

# %%
df.corr(numeric_only=True)
# Out:
#                           id       Age  Academic Pressure  Work Pressure  \
# id                  1.000000  0.003783           0.005172       0.001261
# Age                 0.003783  1.000000          -0.075803       0.002015
# Academic Pressure   0.005172 -0.075803           1.000000      -0.022231
# Work Pressure       0.001261  0.002015          -0.022231       1.000000
# CGPA               -0.012324  0.005056          -0.022239      -0.050896
# Study Satisfaction  0.007794  0.009235          -0.110988      -0.021145
# Job Satisfaction    0.001931 -0.000432          -0.024945       0.770652
# Work/Study Hours   -0.004466 -0.032928           0.095970      -0.005468
# Depression          0.000923 -0.226422           0.474835      -0.003351
#
#                         CGPA  Study Satisfaction  Job Satisfaction  \
# id                 -0.012324            0.007794          0.001931
# Age                 0.005056            0.009235         -0.000432
# ...

# %%
df["Sleep Duration"].hist()
# Out:
# <Axes: >

# %%
df["Academic Pressure"].hist()
# Out:
# <Axes: >

# %%
variables_continuas=["Age","Academic Pressure","Work Pressure","CGPA","Study Satisfaction","Job Satisfaction","Work/Study Hours"]
variables_categoricas=["Gender","Profession","City","Sleep Duration"," Dietary Habits","Degree","have you ever had suicidal thoughts ?","Financial Stress","Family History of Mental Illness"]

# %%
plt.figure(figsize=(12,8))

plt.subplot(4,4,1)
plt.hist(df["Age"], color="green")
plt.title("Age")

plt.subplot(4,4,2)
plt.hist(df["Academic Pressure"], color= "red")
plt.title("Academic Pressure")

plt.subplot(4,4,3)
plt.hist(df["Work Pressure"], color="lightcoral")
plt.title("Work Pressure")

plt.subplot(4,4,4)
plt.hist(df["CGPA"], color= "blue")
plt.title("CGPA")

plt.subplot(4,4,5)
plt.hist(df["Study Satisfaction"], color="skyblue")
plt.title("Study Satisfaction")

plt.subplot(4,4,6)
plt.hist(df["Job Satisfaction"], color="lightgreen")
plt.title("Job Satisfaction")

plt.subplot(4,4,7)
plt.hist(df["Work/Study Hours"], color="gold")
plt.title("Work/Study Hours")

plt.subplot(4,4,8)
plt.hist(df["Academic Pressure"],color="purple")
plt.title("Academic Pressure")

plt.subplot(4,4,9)
plt.hist(df["Financial Stress"],color="Grey")
plt.title("Financial Stress")

plt.tight_layout()
plt.show()

# %%
df["Depression"].hist()
# Out:
# <Axes: >

# %%
df["Profession"].value_counts().plot(kind='bar', color="green")
# Out:
# <Axes: xlabel='Profession'>

# %%
df["Gender"].value_counts().plot(kind='bar', color="orange")
# Out:
# <Axes: xlabel='Gender'>

# %%
df["Dietary Habits"].value_counts().plot(kind='bar', color= "grey")
# Out:
# <Axes: xlabel='Dietary Habits'>

# %%
plt.figure(figsize=(14, 6))  
df["City"].value_counts().head(30).plot(kind='bar', color='skyblue')

plt.xticks(rotation=60, fontsize=8)  
plt.title("Frecuencia por Ciudad")
plt.tight_layout()  
plt.show()

# %%
df["Degree"].value_counts().plot(kind='bar', color="blue")
# Out:
# <Axes: xlabel='Degree'>

# %%
df["Family History of Mental Illness"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Family History of Mental Illness'>

# %%
df["Sleep Duration"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sleep Duration'>

# %%
df.corr(numeric_only=True)
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df["Age"].describe()
# Out:
# count    27901.000000
# mean        25.822300
# std          4.905687
# min         18.000000
# 25%         21.000000
# 50%         25.000000
# 75%         30.000000
# max         59.000000
# Name: Age, dtype: float64

# %%
plt.hist(df["Age"], color="green")
plt.title("Age")
plt.show()

# %%
plt.hist(df["Academic Pressure"], color= "red")
plt.title("Academic Pressure")
# Out:
# Text(0.5, 1.0, 'Academic Pressure')

# %%
df["Academic Pressure"].describe()
# Out:
# count    27901.000000
# mean         3.141214
# std          1.381465
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Academic Pressure, dtype: float64

# %%
df["Work Pressure"].describe()
# Out:
# count    27901.000000
# mean         0.000430
# std          0.043992
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          5.000000
# Name: Work Pressure, dtype: float64

# %%
plt.hist(df["Work Pressure"], color="lightcoral")
plt.title("Work Pressure")
# Out:
# Text(0.5, 1.0, 'Work Pressure')

# %%
plt.hist(df["CGPA"], color= "blue")
plt.title("CGPA")
# Out:
# Text(0.5, 1.0, 'CGPA')

# %%
df["CGPA"].describe()
# Out:
# count    27901.000000
# mean         7.656104
# std          1.470707
# min          0.000000
# 25%          6.290000
# 50%          7.770000
# 75%          8.920000
# max         10.000000
# Name: CGPA, dtype: float64

# %%
df["Study Satisfaction"].describe()
# Out:
# count    27901.000000
# mean         2.943837
# std          1.361148
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Study Satisfaction, dtype: float64

# %%
plt.hist(df["Study Satisfaction"], color="skyblue")
plt.title("Study Satisfaction")
# Out:
# Text(0.5, 1.0, 'Study Satisfaction')

# %%
plt.hist(df["Job Satisfaction"], color="lightgreen")
plt.title("Job Satisfaction")
# Out:
# Text(0.5, 1.0, 'Job Satisfaction')

# %%
df["Work/Study Hours"].describe()
# Out:
# count    27901.000000
# mean         7.156984
# std          3.707642
# min          0.000000
# 25%          4.000000
# 50%          8.000000
# 75%         10.000000
# max         12.000000
# Name: Work/Study Hours, dtype: float64

# %%
plt.hist(df["Work/Study Hours"], color="gold")
plt.title("Work/Study Hours")
# Out:
# Text(0.5, 1.0, 'Work/Study Hours')

# %%
df["Work/Study Hours"]. unique()
# Out:
# array([ 3.,  9.,  4.,  1.,  0., 12.,  2., 11., 10.,  6.,  8.,  5.,  7.])

# %%
df["Gender"].describe()
# Out:
# count     27901
# unique        2
# top        Male
# freq      15547
# Name: Gender, dtype: object

# %%
df["City"].describe()
# Out:
# count      27901
# unique        52
# top       Kalyan
# freq        1570
# Name: City, dtype: object

# %%
df["Degree"].describe()
# Out:
# count          27901
# unique            28
# top       'Class 12'
# freq            6080
# Name: Degree, dtype: object

# %%
df["Degree"].unique()
# Out:
# array(['B.Pharm', 'BSc', 'BA', 'BCA', 'M.Tech', 'PhD', "'Class 12'",
#        'B.Ed', 'LLB', 'BE', 'M.Ed', 'MSc', 'BHM', 'M.Pharm', 'MCA', 'MA',
#        'B.Com', 'MD', 'MBA', 'MBBS', 'M.Com', 'B.Arch', 'LLM', 'B.Tech',
#        'BBA', 'ME', 'MHM', 'Others'], dtype=object)

# %%
df["Have you ever had suicidal thoughts ?"].value_counts().plot(kind='bar', color="red")
plt.title("Have you ever had suicidal thoughts ?")
# Out:
# Text(0.5, 1.0, 'Have you ever had suicidal thoughts ?')

# %%
df["Financial Stress"].value_counts().plot(kind='bar', color="Silver")
plt.title("Financial Stress")
# Out:
# Text(0.5, 1.0, 'Financial Stress')

# %%
df["Family History of Mental Illness"].value_counts().plot(kind='bar', color= "purple")
plt.title("Family History of Mental Illness")
# Out:
# Text(0.5, 1.0, 'Family History of Mental Illness')

# %%
degree_map={
    'B.Pharm':'Grado Universitario',
    'BSc':'Grado Universitario',
    'BA':'Grado Universitario',
    'BCA':'Grado Universitario',
    'M.Tech':'Máster',
    'PhD':'Grado Universitario',
    "'Class 12'":'Estudios Secundaria',
    'B.Ed':'Grado Universitario',
    'LLB':'Grado Universitario',
    'BE':'Grado Universitario',
    'M.Ed':'Máster',
    'MSc':'Máster',
    'BHM':'Grado Universitario',
    'M.Pharm':'Máster',
    'MCA':'Máster',
    'MA':'Máster',
    'B.Com': 'Grado Universitario',
    'MD':'Máster',
    'MBA':'Máster',
    'MBBS': 'Máster',
    'M.Com':'Máster',
    'B.Arch': 'Grado Universitario',
    'LLM': 'Máster',
    'B.Tech':'Grado Universitario',
    'BBA':'Grado Universitario',
    'ME':'Máster',
    'MHM':'Máster'
}

# %%
df["Degree_Tram"]=df["Degree"].map(degree_map)

# %%
print(df["Degree_Tram"].value_counts())
# Out:
# Degree_Tram
# Grado Universitario    13161
# Máster                  8625
# Estudios Secundaria     6080
# Name: count, dtype: int64

# %%
df["Degree_Tram"].value_counts().plot(kind='bar', color= "purple")
plt.title("Degree_Tram")
# Out:
# Text(0.5, 1.0, 'Degree_Tram')
